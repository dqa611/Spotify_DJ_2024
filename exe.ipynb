# %%
from QuocAnh_py.others.install_packages import import_or_install_packages
from QuocAnh_py.execute.widgets_to_main import Main
import_or_install_packages()

# %%
main = Main()
main.lets_dj()
# Out:
# GridBox(children=(VBox(children=(Label(value='Data Availability'), Text(value='Spotify Data is available at: .…
# Importing settings from settings_manual.json
# ./settings_manual.json saved!
# Getting the Spotify playlist data from ./data/spotify_playlist_data.csv
# Track: Yellow  by ['Coldplay']. Album: Parachutes. Track ID 3AJwUDP919kvQ9QcozQPxg
# Selecting the intersection of all keys: common_text_score|harmonic_keys|nearest_neighbor
# Track input 3AJwUDP919kvQ9QcozQPxg, '['Yellow']'
# Apply randomization from settings.json
# Choosing the best next track by selecting the first index
# Searching ['Yellow']'s best next track
# Selecting the intersection of all keys: common_text_score|harmonic_keys|nearest_neighbor
# Searching ['Blinding Lights']'s best next track
# Selecting the intersection of all keys: common_text_score|harmonic_keys|nearest_neighbor
# Searching ['Heart Attack']'s best next track
# Selecting the intersection of all keys: common_text_score|harmonic_keys|nearest_neighbor
# Searching ['Cruel Summer']'s best next track
# Selecting the intersection of all keys: common_text_score|harmonic_keys|nearest_neighbor
# Searching ['As It Was']'s best next track
# Selecting the intersection of all keys: common_text_score|harmonic_keys|nearest_neighbor
# Searching ['Thunder']'s best next track
# Selecting the intersection of all keys: common_text_score|harmonic_keys|nearest_neighbor
# Searching ['505']'s best next track
# The model results from '['505']' don't have any intersection besides the input index. Moving on to applying preferred order
# Select track from intersection: common_text_score|nearest_neighbor
# Searching ['Chop Suey!']'s best next track
# The model results from '['Chop Suey!']' don't have any intersection besides the input index. Moving on to applying preferred order
# Select track from intersection: common_text_score|nearest_neighbor
# Playlist sorted successfully. Total duration: 33 minutes
# My Playlist was created successfully.
# Printing Pairplot of the imported playlist
# Highlighting input indices in the pair plot
# Printing WordCloud of the imported playlist
# Printing My Playlist Summary
# Printing WordCloud of the My Playlist
# Printing My Playlist
#                              track_name            artist  \
# track_id
# 3AJwUDP919kvQ9QcozQPxg           Yellow          Coldplay
# 0VjIjW4GlUZAMYd2vXMi3b  Blinding Lights        The Weeknd
# 1V6gIisPpYqgFeWbMLI0bA     Heart Attack       Demi Lovato
# 1BxfuPKGuaTgP7aM0Bbdwr     Cruel Summer      Taylor Swift
# 4Dvkj6JhhA12EX05fT7y2e        As It Was      Harry Styles
# 1zB4vmk8tFRmM9UULNzbLB          Thunder   Imagine Dragons
# 58ge6dfP91o9oXMzq3XkIS              505    Arctic Monkeys
# 2DlHlPMa4M17kufBvI2lEN       Chop Suey!  System Of A Down
# 2EoOZnxNgtmZaD8uUmz2nD   Black Hole Sun       Soundgarden
#
#                                      artist_id  \
# track_id
# 3AJwUDP919kvQ9QcozQPxg  4gzpq5DPGxSnKTe4SA8HAU
# 0VjIjW4GlUZAMYd2vXMi3b  1Xyo4u8uXC1ZmMpatF05PJ
# 1V6gIisPpYqgFeWbMLI0bA  6S2OmqARrzebs0tKUEyXyp
# track_id
# 3AJwUDP919kvQ9QcozQPxg        Same mood          0.0        0.0
# 0VjIjW4GlUZAMYd2vXMi3b        Same mood          1.0        0.0
# 1V6gIisPpYqgFeWbMLI0bA        Same mood          1.0        0.0
# 1BxfuPKGuaTgP7aM0Bbdwr        Same mood          1.0        0.0
# 4Dvkj6JhhA12EX05fT7y2e      Darken mood          0.0       -1.0
# 1zB4vmk8tFRmM9UULNzbLB    Brighten mood          1.0        1.0
# 58ge6dfP91o9oXMzq3XkIS        Same mood          0.0        0.0
# 2DlHlPMa4M17kufBvI2lEN              NaN          NaN        NaN
# 2EoOZnxNgtmZaD8uUmz2nD              NaN          NaN        NaN
#
#                                   desc  nn_score  nn_index_position  \
# track_id
# 3AJwUDP919kvQ9QcozQPxg      Same scale  0.000000                0.0
# 0VjIjW4GlUZAMYd2vXMi3b   Up whole step  1.853125                3.0
# 1V6gIisPpYqgFeWbMLI0bA      Up a fifth  1.016389                2.0
# 1BxfuPKGuaTgP7aM0Bbdwr    Up half step  0.786807                1.0
# 4Dvkj6JhhA12EX05fT7y2e     Tonal shift  0.978014                1.0
# 1zB4vmk8tFRmM9UULNzbLB  Minor to Major  2.160022                3.0
# 58ge6dfP91o9oXMzq3XkIS      Same scale  1.577272                2.0
# 2DlHlPMa4M17kufBvI2lEN             NaN  1.108261                3.0
# 2EoOZnxNgtmZaD8uUmz2nD             NaN  1.405850                3.0
#
#                                                             intersection  \
# track_id
# 3AJwUDP919kvQ9QcozQPxg  common_text_score|harmonic_keys|nearest_neighbor
# 0VjIjW4GlUZAMYd2vXMi3b  common_text_score|harmonic_keys|nearest_neighbor
# 1V6gIisPpYqgFeWbMLI0bA  common_text_score|harmonic_keys|nearest_neighbor
# 1BxfuPKGuaTgP7aM0Bbdwr  common_text_score|harmonic_keys|nearest_neighbor
# 4Dvkj6JhhA12EX05fT7y2e  common_text_score|harmonic_keys|nearest_neighbor
# 1zB4vmk8tFRmM9UULNzbLB  common_text_score|harmonic_keys|nearest_neighbor
# 58ge6dfP91o9oXMzq3XkIS  common_text_score|harmonic_keys|nearest_neighbor
# 2DlHlPMa4M17kufBvI2lEN                common_text_score|nearest_neighbor
# 2EoOZnxNgtmZaD8uUmz2nD                common_text_score|nearest_neighbor
#
#                         intersection_num  order cum_duration
# track_id
# 3AJwUDP919kvQ9QcozQPxg                 3    0.0         4.45
# 0VjIjW4GlUZAMYd2vXMi3b                 3    1.0         7.78
# 1V6gIisPpYqgFeWbMLI0bA                 3    2.0        11.29
# 1BxfuPKGuaTgP7aM0Bbdwr                 3    3.0        14.26
# 4Dvkj6JhhA12EX05fT7y2e                 3    4.0        17.05
# 1zB4vmk8tFRmM9UULNzbLB                 3    5.0        20.17
# 58ge6dfP91o9oXMzq3XkIS                 3    6.0        24.40
# 2DlHlPMa4M17kufBvI2lEN                 2    7.0        27.90
# 2EoOZnxNgtmZaD8uUmz2nD                 2    8.0        33.21
#
# [9 rows x 43 columns]
